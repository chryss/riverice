# %%
import pandas as pd
from pathlib import Path

# %%
fiwepsdir = Path("/Volumes/CWMobileSSD/ABoVE_WAK/")

# %%
cjcpath = fiwepsdir / "predictors_DF/teleconnections.csv"
predictor_df = pd.read_csv(cjcpath)
# predictor_df = predictor_df[predictor_df.year.between(1979, 2020) ].reset_index().dropna(axis=1)
# predictor_df.drop(columns=['doy', 'tod'], inplace=True)
predictor_df
# Out:
#     Year  AO_JF  AO_MA  EP-NP_JF  EP-NP_MA  PNA_JF  PNA_MA  SOI_JF  SOI_MA  \
# 0   1980 -1.500 -0.926     0.695    -0.300   0.510   0.510    0.60   -0.85
# 1   1981 -0.224 -0.608     0.495    -0.080   1.335   0.020    0.15   -1.15
# 2   1982  0.045  1.264     1.135    -0.285  -1.475  -1.870    1.20    0.55
# 3   1983 -0.224 -0.652    -0.310    -0.530   1.155   1.505   -5.90   -2.75
# 4   1984  0.301 -1.335    -1.190    -0.360   0.665   1.245    0.85    0.10
# 5   1985 -2.123  0.602    -0.705    -1.155   0.225  -1.230    0.75    1.60
# 6   1986 -1.736  1.017     0.675    -0.745   0.505   0.180   -0.05    0.65
# 7   1987 -1.310 -0.680    -0.615     0.025   0.600   1.195   -1.60   -2.20
# 8   1988 -0.401 -0.379     0.500    -0.185   0.700   0.750   -0.40    0.65
# 9   1989  3.192  0.640     0.265     0.945  -1.640  -1.165    2.25    2.25
# 10  1990  2.202  2.434    -1.220     0.875  -1.935  -0.290   -1.55   -0.20
# ...

# %%
predictor_df.columns
# Out:
# Index(['Year', 'AO_JF', 'AO_MA', 'EP-NP_JF', 'EP-NP_MA', 'PNA_JF', 'PNA_MA',
#        'SOI_JF', 'SOI_MA', 'Nino1+2_JF', 'Nino1+2_MA', 'Nino3_JF', 'Nino3_MA',
#        'Nino3.4_JF', 'Nino3.4_MA', 'Nino4_JF', 'Nino4_MA', 'ONI_JF', 'ONI_MA',
#        'PDO_JF', 'PDO_MA', 'NPI_JF', 'NPI_MA', 'NAO_JF', 'NAO_MA', 'EA_JF',
#        'EA_MA', 'WP_JF', 'WP_MA', 'EA-WR_JF', 'EA-WR_MA', 'SCA_JF', 'SCA_MA',
#        'POL_JF', 'POL_MA'],
#       dtype='object')
